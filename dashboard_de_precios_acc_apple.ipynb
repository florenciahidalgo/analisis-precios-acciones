# %%
import pandas as pd
import yfinance as yf
from sqlalchemy import create_engine

# %%
# Descargar datos
tickers = ['AAPL', 'MSFT', 'GOOGL', 'TSLA']
dfs = []

for t in tickers:
    df = yf.download(t, start='2018-01-01', progress=False)
    df.reset_index(inplace=True)

    # asignamos orden de columnas
    df = df[['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    df.columns = ['date', 'open', 'high', 'low', 'close', 'volume']

    df['ticker'] = t
    dfs.append(df)

# organizamos los datos de manera vertical
stocks_df = pd.concat(dfs, axis=0, ignore_index=True)

# Guardar datos en csv
stocks_df.to_csv('stocks.csv', index=False)

# %%
# limpiamos datos
stocks_df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# ticker    0
# dtype: int64

# %%
# leer datos desde csv
stocks_df = pd.read_csv('stocks.csv')

# creamos conexion a PostgreSQL
engine = create_engine('postgresql+psycopg2://postgres:root123@localhost:5432/stocks_db')

conn = engine.connect()

print("Conexión exitosa a la base de datos PostgreSQL")

conn.close()
# Out:
# Conexión exitosa a la base de datos PostgreSQL

# %%
# mandar stocks_df a PostgreSQL
stocks_df.to_sql('stocks_data', engine, if_exists='replace', index=False)
# Out:
# 98
